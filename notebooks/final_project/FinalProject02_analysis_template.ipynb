# %% [markdown]
# # Final Project 2: Analysis Template
#
# This template is designed to run from top to bottom. Keep code, figures,
# interpretation, and verification checks together.

# %% [markdown]
# ## Proposal and Project-Setup Debrief (First 20 Minutes)
#
# Before project analysis begins, groups report one scope, data-access, role, or method problem from the proposal workshop. Include evidence and the next check. The class will examine one unresolved setup problem together.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "data").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"
PROCESSED_DIR = DATA_DIR / "processed"
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

print(f"Project root: {PROJECT_ROOT}")
print(f"Processed data folder exists: {PROCESSED_DIR.exists()}")

# %% [markdown]
# ## Introduction
#
# State the research question and why it matters.
#
# ## Dataset description
#
# Describe variables, units, date range, site or spatial domain, and source.
#
# ## Data cleaning
#
# Explain any filtering, missing-value handling, or unit conversion.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Replace this file with the dataset selected by your group.
data = pd.read_csv(PROCESSED_DIR / "iowa_streamflow_daily.csv", parse_dates=["date"])
print(data.head())

# %% [markdown]
# ## Methods
#
# Describe the computational method clearly enough that another student could reproduce it.
#
# ## Results and figures

# %%
fig, ax = plt.subplots(figsize=(9, 4))
ax.plot(data["date"], data["discharge_cfs"], linewidth=0.8)
ax.set_xlabel("Date")
ax.set_ylabel("Discharge (cfs)")
ax.set_title("Example final-project figure")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation
#
# Explain the result using the data and method.
#
# ## Uncertainty and limitations
#
# ## Reproducibility notes
#
# ## AI usage disclosure
#
# ## Verification checks
#
# ## Rejected AI suggestions
#
# ## Statement of human responsibility
#
# We reviewed, ran, and verified the code and figures submitted in this notebook.
