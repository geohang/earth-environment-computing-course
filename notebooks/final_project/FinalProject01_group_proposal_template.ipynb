# %% [markdown]
# # Final Project 1: Group Proposal Template
#
# Use this notebook to plan a feasible group project before analysis begins.

# %% [markdown]
# ## Group Lab 6 Debrief and Collaborative Debugging (First 10 Minutes)
#
# Open the debrief card from Group Lab 6. Share model, unit, calibration, or interpretation problems before beginning the project proposal. The class will work through one unresolved problem and record a lesson that applies to project planning.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "data").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data"
PROCESSED_DIR = DATA_DIR / "processed"
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

print(f"Project root: {PROJECT_ROOT}")
print(f"Processed data folder exists: {PROCESSED_DIR.exists()}")

# %% [markdown]
# ## Project title
#
# ## Group members
#
# ## Research question
#
# ## Earth or environmental motivation
#
# ## Dataset
#
# Include the data source and citation. If your dataset is outside the course repository, confirm it with the instructor first.
#
# ## Planned computational method
#
# Choose one main method: statistics, interpolation, simple environmental modeling,
# spatial analysis, time-series analysis, or visualization-based analysis.
#
# ## Planned figures
#
# List two or three figures that would answer the research question.
#
# ## Expected challenges
#
# ## Group role division
#
# ## Planned AI use, if any
#
# ## How the group will verify AI-assisted code
#
# ## Person responsible for reviewing each AI-assisted component

# %%
# Optional: list available processed datasets.
for path in sorted(PROCESSED_DIR.glob("*.csv")):
    print(path.name)
